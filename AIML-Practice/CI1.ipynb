# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 2    3.0            4.7           3.2            1.3           0.2
# 3    4.0            4.6           3.1            1.5           0.2
# 4    5.0            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 162  NaN            NaN           6.0            NaN           NaN
# 163  NaN            NaN          66.0            NaN           NaN
# 164  NaN            NaN           NaN            NaN           NaN
# 165  NaN            NaN           6.0            NaN           NaN
# 166  NaN            NaN           6.0            NaN           NaN
#
#          Species
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# ..           ...
# 162          NaN
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  147.000000     149.000000    158.000000     158.000000    150.000000
# mean    75.673469       6.318792      4.038608       3.848734      1.198667
# std     43.812671       3.486448      7.086838       1.736779      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     37.500000       5.100000      2.800000       1.600000      0.300000
# 50%     76.000000       5.800000      3.000000       4.500000      1.300000
# 75%    113.500000       6.500000      3.400000       5.100000      1.800000
# max    150.000000      40.000000     66.000000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             147 non-null    float64
#  1   SepalLengthCm  149 non-null    float64
#  2   SepalWidthCm   158 non-null    float64
#  3   PetalLengthCm  158 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 8.0+ KB

# %%
df.plot(kind='bar',y='SepalWidthCm',x='SepalLengthCm')
plt.title("SepalWidthCm of bar graph")
plt.show()

# %%
plt.hist(df['PetalLengthCm'])
plt.title("PetolLength of histogram")
plt.ylabel("petol lenght")
plt.show()

# %%
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'],color='red') 
plt.title("scatter plot")
plt.xlabel("SepalWidthCm")
plt.ylabel("SepalLengthCm")
plt.show()

# %%
df1=pd.read_csv("D:/rainfall.csv")
df1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...

# %%
df1=df1.drop('JAN',axis=1)

# %%
df1
# Out:
#                     SUBDIVISION  YEAR    FEB    MAR    APR    MAY    JUN  \
# 0     Andaman & Nicobar Islands  1901   87.1   29.2    2.3  528.8  517.5
# 1     Andaman & Nicobar Islands  1902  159.8   12.2    0.0  446.1  537.1
# 2     Andaman & Nicobar Islands  1903  144.0    0.0    1.0  235.1  479.9
# 3     Andaman & Nicobar Islands  1904   14.7    0.0  202.4  304.5  495.1
# 4     Andaman & Nicobar Islands  1905    0.0    3.3   26.9  279.5  628.7
# ...                         ...   ...    ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013   34.4   37.5    5.3   88.3  426.2
# 4184                Lakshadweep  2014   16.1    4.4   14.9   57.4  244.1
# 4185                Lakshadweep  2015    0.5    3.7   87.1  133.1  296.6
# 4186                Lakshadweep  2016   12.1    3.2    2.6   77.4  321.1
# 4187                Lakshadweep  2017    0.9  100.2    1.8  145.7  521.9
#
#         JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# ...

# %%
df1['ANNUAL'].max()
# Out:
# np.float64(6331.1)

# %%
df1=df1['
